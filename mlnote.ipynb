# %%
import numpy as np
import matplotlib.pyplot as plt

Xorig = plt.imread('AP_gray.png')
#rows, cols = np.shape(Xorig)
#noise = np.random.randn(rows, cols)
#Xstd = np.add(Xorig, noise)
plt.imshow(Xorig, cmap="gray")
plt.title("Original Image: Arthur")
# Out:
# Text(0.5, 1.0, 'Original Image: Arthur')

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import * 
x = np.arange(-5,5,0.1) 
# y = np.tanh(x)
y = np.sign(x) * np.maximum(np.abs(x)-2,0)


plt.plot(x,y)
plt.show()

# %%
for k in range(11,1):
    a = k
    print(a)
